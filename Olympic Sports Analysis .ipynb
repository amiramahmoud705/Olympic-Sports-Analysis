# %% [markdown]
# # Project - Olympic Sports Analysis

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
sns.set()

# %%
summer = pd.read_csv('C:/Users/The world/Desktop/Tasks/summer.csv')
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
winter = pd.read_csv('C:/Users/The world/Desktop/Tasks/winter.csv')
winter
# Out:
#       Year      City     Sport Discipline               Athlete Country  \
# 0     1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA
# 1     1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA
# 2     1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA
# 3     1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA
# 4     1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI
# ...    ...       ...       ...        ...                   ...     ...
# 5765  2014     Sochi    Skiing  Snowboard          JONES, Jenny     GBR
# 5766  2014     Sochi    Skiing  Snowboard       ANDERSON, Jamie     USA
# 5767  2014     Sochi    Skiing  Snowboard    MALTAIS, Dominique     CAN
# 5768  2014     Sochi    Skiing  Snowboard          SAMKOVA, Eva     CZE
# 5769  2014     Sochi    Skiing  Snowboard      TRESPEUCH, Chloe     FRA
#
#      Gender            Event   Medal
# 0       Men  Military Patrol  Bronze
# ...

# %%
countries = pd.read_csv('C:/Users/The world/Desktop/Tasks/dictionary.csv')
countries
# Out:
#              Country Code  Population  GDP per Capita
# 0        Afghanistan  AFG  32526562.0      594.323081
# 1            Albania  ALB   2889167.0     3945.217582
# 2            Algeria  ALG  39666519.0     4206.031232
# 3    American Samoa*  ASA     55538.0             NaN
# 4            Andorra  AND     70473.0             NaN
# ..               ...  ...         ...             ...
# 196          Vietnam  VIE  91703800.0     2111.138024
# 197  Virgin Islands*  ISV    103574.0             NaN
# 198            Yemen  YEM  26832215.0     1406.291651
# 199           Zambia  ZAM  16211767.0     1304.879014
# 200         Zimbabwe  ZIM  15602751.0      924.143819
#
# [201 rows x 4 columns]

# %% [markdown]
# #### Inspecting Datasets

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
winter.head()
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %%
winter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5770 entries, 0 to 5769
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        5770 non-null   int64
#  1   City        5770 non-null   object
#  2   Sport       5770 non-null   object
#  3   Discipline  5770 non-null   object
#  4   Athlete     5770 non-null   object
#  5   Country     5770 non-null   object
#  6   Gender      5770 non-null   object
#  7   Event       5770 non-null   object
#  8   Medal       5770 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 405.8+ KB

# %%
countries.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         201 non-null    object
#  1   Code            201 non-null    object
#  2   Population      196 non-null    float64
#  3   GDP per Capita  176 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 6.4+ KB

# %%
##Listing all of the missing data in the 'countries' dataframe
countries.isnull().sum()
# Out:
# Country            0
# Code               0
# Population         5
# GDP per Capita    25
# dtype: int64

# %%
countries[countries.isnull().any(axis=1)].reset_index(drop=True)
# Out:
#                             Country Code  Population  GDP per Capita
# 0                   American Samoa*  ASA     55538.0             NaN
# 1                           Andorra  AND     70473.0             NaN
# 2                            Aruba*  ARU    103889.0             NaN
# 3                          Bermuda*  BER     65235.0             NaN
# 4            British Virgin Islands  IVB     30117.0             NaN
# 5                   Cayman Islands*  CAY     59967.0             NaN
# 6                      Cook Islands  COK         NaN             NaN
# 7                              Cuba  CUB  11389562.0             NaN
# 8                           Eritrea  ERI         NaN             NaN
# 9                              Guam  GUM    169885.0             NaN
# 10                             Iran  IRI  79109272.0             NaN
# 11                     Korea, North  PRK  25155317.0             NaN
# 12                            Libya  LBA   6278438.0             NaN
# ...

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
# Modify the full name of the athletes in Winter and Summer editions
summer['Athlete'] = summer['Athlete'].str.split(', ').str[::-1].str.join(' ')
summer['Athlete'] = summer['Athlete'].str.title()
summer.head()
# Out:
#    Year    City     Sport Discipline            Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       Alfred Hajos     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    Otto Herschmann     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   Dimitrios Drivas     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  Ioannis Malokinis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  Spiridon Chasapis     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer=summer.merge(countries,how='left' , left_on='Country' , right_on='Code')
summer.head()
# Out:
#    Year    City     Sport Discipline            Athlete Country_x Gender  \
# 0  1896  Athens  Aquatics   Swimming       Alfred Hajos       HUN    Men
# 1  1896  Athens  Aquatics   Swimming    Otto Herschmann       AUT    Men
# 2  1896  Athens  Aquatics   Swimming   Dimitrios Drivas       GRE    Men
# 3  1896  Athens  Aquatics   Swimming  Ioannis Malokinis       GRE    Men
# 4  1896  Athens  Aquatics   Swimming  Spiridon Chasapis       GRE    Men
#
#                         Event   Medal Country_y Code  Population  \
# 0              100M Freestyle    Gold   Hungary  HUN   9844686.0
# 1              100M Freestyle  Silver   Austria  AUT   8611088.0
# 2  100M Freestyle For Sailors  Bronze    Greece  GRE  10823732.0
# 3  100M Freestyle For Sailors    Gold    Greece  GRE  10823732.0
# 4  100M Freestyle For Sailors  Silver    Greece  GRE  10823732.0
#
#    GDP per Capita
# 0    12363.543460
# 1    43774.985174
# 2    18002.230578
# 3    18002.230578
# 4    18002.230578

# %%
summer=summer[['Year','City','Sport','Discipline','Athlete','Country_x','Gender','Event','Medal','Country_y']]
summer.columns=['Year','City','Sport','Discipline','Athlete','Code','Gender','Event','Medal','Country']
summer.head()
# Out:
#    Year    City     Sport Discipline            Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       Alfred Hajos  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    Otto Herschmann  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   Dimitrios Drivas  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  Ioannis Malokinis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  Spiridon Chasapis  GRE    Men
#
#                         Event   Medal  Country
# 0              100M Freestyle    Gold  Hungary
# 1              100M Freestyle  Silver  Austria
# 2  100M Freestyle For Sailors  Bronze   Greece
# 3  100M Freestyle For Sailors    Gold   Greece
# 4  100M Freestyle For Sailors  Silver   Greece

# %%
# The highest male athlete of all Summer editions 
highest_male = summer[summer['Gender'] == 'Men']['Athlete'].value_counts().index[0]
highest_male
# Out:
# 'Michael Phelps'

# %%
# His total number of medals
phelps_medals = summer[summer['Athlete'] == 'Michael Phelps']
medal_counts = phelps_medals['Medal'].value_counts().sum()
medal_counts
# Out:
# 22

# %%
# The highest female athlete of all Summer editions 
highest_female = summer[summer['Gender'] == 'Women']['Athlete'].value_counts().index[0]
highest_female
# Out:
# 'Larisa Latynina'

# %%
# Her total number of medals
Larisa_medals = summer[summer['Athlete'] == 'Larisa Latynina']
Larisa_medal_counts = Larisa_medals['Medal'].value_counts().sum()
Larisa_medal_counts
# Out:
# 18

# %% [markdown]
# ###  Find the highest athletes regarding to each medal type in the Summer editions

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline            Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       Alfred Hajos  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    Otto Herschmann  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   Dimitrios Drivas  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  Ioannis Malokinis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  Spiridon Chasapis  GRE    Men
#
#                         Event   Medal  Country
# 0              100M Freestyle    Gold  Hungary
# 1              100M Freestyle  Silver  Austria
# 2  100M Freestyle For Sailors  Bronze   Greece
# 3  100M Freestyle For Sailors    Gold   Greece
# 4  100M Freestyle For Sailors  Silver   Greece

# %%
# Let's discover what does 'Michael Phelps' have of medals  
summer[summer.Athlete == 'Michael Phelps']
# Out:
#        Year     City     Sport Discipline         Athlete Code Gender  \
# 25225  2004   Athens  Aquatics   Swimming  Michael Phelps  USA    Men
# 25253  2004   Athens  Aquatics   Swimming  Michael Phelps  USA    Men
# 25258  2004   Athens  Aquatics   Swimming  Michael Phelps  USA    Men
# 25265  2004   Athens  Aquatics   Swimming  Michael Phelps  USA    Men
# 25277  2004   Athens  Aquatics   Swimming  Michael Phelps  USA    Men
# 25286  2004   Athens  Aquatics   Swimming  Michael Phelps  USA    Men
# 25325  2004   Athens  Aquatics   Swimming  Michael Phelps  USA    Men
# 25361  2004   Athens  Aquatics   Swimming  Michael Phelps  USA    Men
# 27224  2008  Beijing  Aquatics   Swimming  Michael Phelps  USA    Men
# 27252  2008  Beijing  Aquatics   Swimming  Michael Phelps  USA    Men
# 27258  2008  Beijing  Aquatics   Swimming  Michael Phelps  USA    Men
# 27264  2008  Beijing  Aquatics   Swimming  Michael Phelps  USA    Men
# ...

# %%
top_medalists = summer.groupby(['Athlete', 'Medal'])['Sport'].count().reset_index().sort_values(by='Sport',ascending = False)
top_medalists
# Out:
#                       Athlete   Medal  Sport
# 17344          Michael Phelps    Gold     18
# 3517               Carl Lewis    Gold      9
# 16581              Mark Spitz    Gold      9
# 19224             Paavo Nurmi    Gold      9
# 14731         Larisa Latynina    Gold      9
# ...                       ...     ...    ...
# 9532          Harald Sandberg  Bronze      1
# 9531        Harald S.A. Julin  Silver      1
# 9529   Harald Oliver Faerstad  Silver      1
# 9528           Harald Norpoth  Silver      1
# 13361          Julie Richards  Bronze      1
#
# [26723 rows x 3 columns]

# %%
top_medalists= top_medalists.drop_duplicates(subset =['Medal'], keep ='first')
top_medalists.rename(columns={'Sport':'Count'}, inplace = True)
top_medalists
# Out:
# C:\Users\The world\AppData\Local\Temp\ipykernel_20604\258764238.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_medalists.rename(columns={'Sport':'Count'}, inplace = True)
#                         Athlete   Medal  Count
# 17344            Michael Phelps    Gold     18
# 7645      Franziska Van Almsick  Bronze      6
# 22307  Shirley Farber Babashoff  Silver      6

# %% [markdown]
# #### Calculate the medals per each country for the best male and females athletes in all of the Summer editions and visualize the results

# %%
df=summer.groupby(['Country','Medal'])['Gender'].count().reset_index().sort_values(by='Gender',ascending=False)
top_medals= df.pivot_table(index='Country', columns='Medal',fill_value=0)
top_medals
# Out:
#                 Gender
# Medal           Bronze   Gold Silver
# Country
# Afghanistan        2.0    0.0    0.0
# Algeria            8.0    5.0    2.0
# Argentina         91.0   69.0   99.0
# Armenia            8.0    1.0    2.0
# Australia        472.0  312.0  405.0
# ...                ...    ...    ...
# Venezuela          8.0    2.0    2.0
# Vietnam            0.0    0.0    2.0
# Virgin Islands*    0.0    0.0    1.0
# Zambia             1.0    0.0    1.0
# Zimbabwe           1.0   18.0    4.0
#
# [129 rows x 3 columns]

# %%
top_10_countries=top_medals.sum(axis=1).nlargest(10)
top_10_countries=top_medals.loc[top_10_countries.index]
top_10_countries
# Out:
#                 Gender
# Medal           Bronze    Gold  Silver
# Country
# United States   1098.0  2235.0  1252.0
# United Kingdom   553.0   546.0   621.0
# France           497.0   408.0   491.0
# Germany          475.0   452.0   378.0
# Italy            404.0   476.0   416.0
# Australia        472.0   312.0   405.0
# Hungary          351.0   412.0   316.0
# Sweden           328.0   349.0   367.0
# Netherlands      339.0   233.0   279.0
# China            221.0   290.0   296.0

# %%
top_10_countries.plot.barh(figsize=(12,12),width=0.7,color=["darkgoldenrod", "gold", "LightGray"])
plt.title("Medals Distribution Of Top 10 Countries (Summer Olympics)")
plt.legend(title="Medal Type")
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 13))

# معالجة بيانات الرجال
men = summer[summer['Gender'] == 'Men']
men = men.groupby(['Athlete', 'Medal'])['Country'].count().reset_index().sort_values(by='Country',ascending=False)
men = men.pivot_table(index='Athlete', columns='Medal', values='Country', fill_value=0)
top_men = men.loc[men.sum(axis=1).nlargest(15).index]
top_men.plot.barh(width=0.8, color=['darkgoldenrod', 'gold', 'LightGray'], ax=ax[0], legend=False)

ax[0].set_title('Best Male Athletes')
ax[0].set_ylabel('Athletes')
ax[0].set_xlabel('Number of medals')

women = summer[summer['Gender'] == 'Women']
women = women.groupby(['Athlete', 'Medal'])['Country'].count().reset_index().sort_values(by='Country',ascending=False)
women = women.pivot_table(index='Athlete', columns='Medal', values='Country', fill_value=0)
top_women = women.loc[women.sum(axis=1).nlargest(15).index] 
top_women.plot.barh(width=0.8, color=['darkgoldenrod', 'gold', 'LightGray'], ax=ax[1], legend=False)

ax[1].set_title('Best Female Athletes')
ax[1].set_ylabel('')
ax[1].set_xlabel('Number of medals')

plt.tight_layout()
plt.show()

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline            Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       Alfred Hajos  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    Otto Herschmann  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   Dimitrios Drivas  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  Ioannis Malokinis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  Spiridon Chasapis  GRE    Men
#
#                         Event   Medal  Country
# 0              100M Freestyle    Gold  Hungary
# 1              100M Freestyle  Silver  Austria
# 2  100M Freestyle For Sailors  Bronze   Greece
# 3  100M Freestyle For Sailors    Gold   Greece
# 4  100M Freestyle For Sailors  Silver   Greece

# %%
winter.head()
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %%
countries.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
olympics = pd.concat([summer, winter], keys = ["Summer", "Winter"], names = ["Edition"]).reset_index().drop(columns = "level_1")
olympics
# Out:
#       Edition  Year    City     Sport Discipline             Athlete Code  \
# 0      Summer  1896  Athens  Aquatics   Swimming        Alfred Hajos  HUN
# 1      Summer  1896  Athens  Aquatics   Swimming     Otto Herschmann  AUT
# 2      Summer  1896  Athens  Aquatics   Swimming    Dimitrios Drivas  GRE
# 3      Summer  1896  Athens  Aquatics   Swimming   Ioannis Malokinis  GRE
# 4      Summer  1896  Athens  Aquatics   Swimming   Spiridon Chasapis  GRE
# ...       ...   ...     ...       ...        ...                 ...  ...
# 36930  Winter  2014   Sochi    Skiing  Snowboard        JONES, Jenny  NaN
# 36931  Winter  2014   Sochi    Skiing  Snowboard     ANDERSON, Jamie  NaN
# 36932  Winter  2014   Sochi    Skiing  Snowboard  MALTAIS, Dominique  NaN
# 36933  Winter  2014   Sochi    Skiing  Snowboard        SAMKOVA, Eva  NaN
# 36934  Winter  2014   Sochi    Skiing  Snowboard    TRESPEUCH, Chloe  NaN
#
#       Gender                       Event   Medal  Country
# ...

# %% [markdown]
# ### 2] Data Cleaning

# %%
olympics
# Out:
#       Edition  Year    City     Sport Discipline             Athlete Code  \
# 0      Summer  1896  Athens  Aquatics   Swimming        Alfred Hajos  HUN
# 1      Summer  1896  Athens  Aquatics   Swimming     Otto Herschmann  AUT
# 2      Summer  1896  Athens  Aquatics   Swimming    Dimitrios Drivas  GRE
# 3      Summer  1896  Athens  Aquatics   Swimming   Ioannis Malokinis  GRE
# 4      Summer  1896  Athens  Aquatics   Swimming   Spiridon Chasapis  GRE
# ...       ...   ...     ...       ...        ...                 ...  ...
# 36930  Winter  2014   Sochi    Skiing  Snowboard        JONES, Jenny  NaN
# 36931  Winter  2014   Sochi    Skiing  Snowboard     ANDERSON, Jamie  NaN
# 36932  Winter  2014   Sochi    Skiing  Snowboard  MALTAIS, Dominique  NaN
# 36933  Winter  2014   Sochi    Skiing  Snowboard        SAMKOVA, Eva  NaN
# 36934  Winter  2014   Sochi    Skiing  Snowboard    TRESPEUCH, Chloe  NaN
#
#       Gender                       Event   Medal  Country
# ...

# %%
olympics.rename(columns = {"Country_x":"Code", "Country_y": "Country"}, inplace = True)

# %%
olympics
# Out:
#       Edition  Year    City     Sport Discipline             Athlete Code  \
# 0      Summer  1896  Athens  Aquatics   Swimming        Alfred Hajos  HUN
# 1      Summer  1896  Athens  Aquatics   Swimming     Otto Herschmann  AUT
# 2      Summer  1896  Athens  Aquatics   Swimming    Dimitrios Drivas  GRE
# 3      Summer  1896  Athens  Aquatics   Swimming   Ioannis Malokinis  GRE
# 4      Summer  1896  Athens  Aquatics   Swimming   Spiridon Chasapis  GRE
# ...       ...   ...     ...       ...        ...                 ...  ...
# 36930  Winter  2014   Sochi    Skiing  Snowboard        JONES, Jenny  NaN
# 36931  Winter  2014   Sochi    Skiing  Snowboard     ANDERSON, Jamie  NaN
# 36932  Winter  2014   Sochi    Skiing  Snowboard  MALTAIS, Dominique  NaN
# 36933  Winter  2014   Sochi    Skiing  Snowboard        SAMKOVA, Eva  NaN
# 36934  Winter  2014   Sochi    Skiing  Snowboard    TRESPEUCH, Chloe  NaN
#
#       Gender                       Event   Medal  Country
# ...

# %% [markdown]
# #### For some Country Codes, there is no corresponding full Country Name available (e.g. for "URS") -> missing values in olympics. Identify these Country Codes and search the Web for the full Country Names. Replace missing values!¶

# %%
# Finding the missing data in the new dataframe
olympics.isna()
# Out:
#        Edition   Year   City  Sport  Discipline  Athlete   Code  Gender  \
# 0        False  False  False  False       False    False  False   False
# 1        False  False  False  False       False    False  False   False
# 2        False  False  False  False       False    False  False   False
# 3        False  False  False  False       False    False  False   False
# 4        False  False  False  False       False    False  False   False
# ...        ...    ...    ...    ...         ...      ...    ...     ...
# 36930    False  False  False  False       False    False   True   False
# 36931    False  False  False  False       False    False   True   False
# 36932    False  False  False  False       False    False   True   False
# 36933    False  False  False  False       False    False   True   False
# 36934    False  False  False  False       False    False   True   False
#
#        Event  Medal  Country
# 0      False  False    False
# 1      False  False    False
# ...

# %%
olympics.isna().sum()
# Out:
# Edition          0
# Year             0
# City             0
# Sport            0
# Discipline       0
# Athlete          0
# Code          5774
# Gender           0
# Event            0
# Medal            0
# Country       5423
# dtype: int64

# %%
# List all of the old countries' codes
olympics[olympics.Country.isnull()].loc[1::].Code.value_counts()
# Out:
# Code
# URS    2049
# GDR     825
# ROU     640
# FRG     490
# YUG     435
# TCH     329
# EUA     260
# EUN     223
# ZZX      48
# SRB      31
# ANZ      29
# RU1      17
# MNE      14
# TTO      10
# BOH       7
# BWI       5
# SGP       4
# IOP       3
# Name: count, dtype: int64

# %%
# Get all of the indicies of the old countries
old_countries = olympics[olympics.Country.isnull()].loc[1::].Code.value_counts().index
old_countries
# Out:
# Index(['URS', 'GDR', 'ROU', 'FRG', 'YUG', 'TCH', 'EUA', 'EUN', 'ZZX', 'SRB',
#        'ANZ', 'RU1', 'MNE', 'TTO', 'BOH', 'BWI', 'SGP', 'IOP'],
#       dtype='object', name='Code')

# %%
mapper = pd.Series(index=old_countries, name = "Country", data = ["Soviet Union", "East Germany", "Romania", "West Germany", "Czechoslovakia",
                               "Yugoslavia", "Unified Team", "Unified Team of Germany", "Mixed teams", "Serbia",
                              "Australasia", "Russian Empire", "Montenegro", "Trinidad and Tobago", "Bohemia", 
                              "West Indies Federation", "Singapore", "Independent Olympic Participants"])

mapper
# Out:
# Code
# URS                        Soviet Union
# GDR                        East Germany
# ROU                             Romania
# FRG                        West Germany
# YUG                      Czechoslovakia
# TCH                          Yugoslavia
# EUA                        Unified Team
# EUN             Unified Team of Germany
# ZZX                         Mixed teams
# SRB                              Serbia
# ANZ                         Australasia
# RU1                      Russian Empire
# MNE                          Montenegro
# TTO                 Trinidad and Tobago
# BOH                             Bohemia
# BWI              West Indies Federation
# SGP                           Singapore
# IOP    Independent Olympic Participants
# Name: Country, dtype: object

# %%
missing_indices = olympics[olympics.Country.isnull()].loc[1::].index
missing_indices
# Out:
# Index([  132,   133,   134,   135,   136,   137,   257,   258,   259,   260,
#        ...
#        30883, 30899, 30900, 30901, 30910, 31072, 31077, 31079, 31091, 31110],
#       dtype='int64', length=5423)

# %%
olympics.loc[missing_indices, "Code"].map(mapper)
# Out:
# 132      Mixed teams
# 133      Mixed teams
# 134      Mixed teams
# 135      Mixed teams
# 136      Mixed teams
#             ...
# 31072            NaN
# 31077        Romania
# 31079        Romania
# 31091            NaN
# 31110            NaN
# Name: Code, Length: 5423, dtype: object

# %%
olympics.Country.fillna(olympics.Code.map(mapper), inplace = True)
olympics.loc[missing_indices]
# Out:
#       Edition  Year    City          Sport           Discipline  \
# 132    Summer  1896  Athens         Tennis               Tennis
# 133    Summer  1896  Athens         Tennis               Tennis
# 134    Summer  1896  Athens         Tennis               Tennis
# 135    Summer  1896  Athens         Tennis               Tennis
# 136    Summer  1896  Athens         Tennis               Tennis
# ...       ...   ...     ...            ...                  ...
# 31072  Summer  2012  London  Weightlifting        Weightlifting
# 31077  Summer  2012  London  Weightlifting        Weightlifting
# 31079  Summer  2012  London  Weightlifting        Weightlifting
# 31091  Summer  2012  London  Weightlifting        Weightlifting
# 31110  Summer  2012  London      Wrestling  Wrestling Freestyle
#
#                         Athlete Code Gender     Event   Medal      Country
# 132                 Edwin Flack  ZZX    Men   Doubles  Bronze  Mixed teams
# ...

# %% [markdown]
# #### Remove rows from olympics where the Country code is unknown

# %%
# Double-check for any missing data
olympics.Code.isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36930     True
# 36931     True
# 36932     True
# 36933     True
# 36934     True
# Name: Code, Length: 36935, dtype: bool

# %%
# Drop these missing records
olympics.dropna(subset = ["Code"], inplace = True)
olympics
# Out:
#       Edition  Year    City      Sport           Discipline  \
# 0      Summer  1896  Athens   Aquatics             Swimming
# 1      Summer  1896  Athens   Aquatics             Swimming
# 2      Summer  1896  Athens   Aquatics             Swimming
# 3      Summer  1896  Athens   Aquatics             Swimming
# 4      Summer  1896  Athens   Aquatics             Swimming
# ...       ...   ...     ...        ...                  ...
# 31160  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31161  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31162  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31163  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31164  Summer  2012  London  Wrestling  Wrestling Freestyle
#
#                         Athlete Code Gender                       Event  \
# 0                  Alfred Hajos  HUN    Men              100M Freestyle
# 1               Otto Herschmann  AUT    Men              100M Freestyle
# ...

# %%
# Reseting indicies to get rid of the deleted records
olympics.reset_index(drop = True, inplace = True)
olympics
# Out:
#       Edition  Year    City      Sport           Discipline  \
# 0      Summer  1896  Athens   Aquatics             Swimming
# 1      Summer  1896  Athens   Aquatics             Swimming
# 2      Summer  1896  Athens   Aquatics             Swimming
# 3      Summer  1896  Athens   Aquatics             Swimming
# 4      Summer  1896  Athens   Aquatics             Swimming
# ...       ...   ...     ...        ...                  ...
# 31156  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31157  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31158  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31159  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31160  Summer  2012  London  Wrestling  Wrestling Freestyle
#
#                         Athlete Code Gender                       Event  \
# 0                  Alfred Hajos  HUN    Men              100M Freestyle
# 1               Otto Herschmann  AUT    Men              100M Freestyle
# ...

# %% [markdown]
# #### Convert the column Medal into an ordered Categorical column ("Bronze" < "Silver" < "Gold")

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31161 entries, 0 to 31160
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Edition     31161 non-null  object
#  1   Year        31161 non-null  int64
#  2   City        31161 non-null  object
#  3   Sport       31161 non-null  object
#  4   Discipline  31161 non-null  object
#  5   Athlete     31161 non-null  object
#  6   Code        31161 non-null  object
#  7   Gender      31161 non-null  object
#  8   Event       31161 non-null  object
#  9   Medal       31161 non-null  object
#  10  Country     31161 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 2.6+ MB

# %%
olympics['Medal'] = olympics['Medal'].astype("category").sort_values()
olympics
# Out:
#       Edition  Year    City      Sport           Discipline  \
# 0      Summer  1896  Athens   Aquatics             Swimming
# 1      Summer  1896  Athens   Aquatics             Swimming
# 2      Summer  1896  Athens   Aquatics             Swimming
# 3      Summer  1896  Athens   Aquatics             Swimming
# 4      Summer  1896  Athens   Aquatics             Swimming
# ...       ...   ...     ...        ...                  ...
# 31156  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31157  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31158  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31159  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31160  Summer  2012  London  Wrestling  Wrestling Freestyle
#
#                         Athlete Code Gender                       Event  \
# 0                  Alfred Hajos  HUN    Men              100M Freestyle
# 1               Otto Herschmann  AUT    Men              100M Freestyle
# ...

# %%
olympics["Medal"] = pd.Categorical(olympics["Medal"], categories=["Bronze", "Silver", "Gold"], ordered=True )
olympics
# Out:
#       Edition  Year    City      Sport           Discipline  \
# 0      Summer  1896  Athens   Aquatics             Swimming
# 1      Summer  1896  Athens   Aquatics             Swimming
# 2      Summer  1896  Athens   Aquatics             Swimming
# 3      Summer  1896  Athens   Aquatics             Swimming
# 4      Summer  1896  Athens   Aquatics             Swimming
# ...       ...   ...     ...        ...                  ...
# 31156  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31157  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31158  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31159  Summer  2012  London  Wrestling  Wrestling Freestyle
# 31160  Summer  2012  London  Wrestling  Wrestling Freestyle
#
#                         Athlete Code Gender                       Event  \
# 0                  Alfred Hajos  HUN    Men              100M Freestyle
# 1               Otto Herschmann  AUT    Men              100M Freestyle
# ...

# %%
olympics.Medal.sort_values()
# Out:
# 31160    Bronze
# 21527    Bronze
# 9352     Bronze
# 9353     Bronze
# 9354     Bronze
#           ...
# 21771      Gold
# 21772      Gold
# 21773      Gold
# 9145       Gold
# 0          Gold
# Name: Medal, Length: 31161, dtype: category
# Categories (3, object): ['Bronze' < 'Silver' < 'Gold']

# %% [markdown]
# #### 3] Data Analysis & Visualization (EDA)

# %% [markdown]
# ### What are the Top 10 Countries by total medals?

# %%
Top_10_Countries_by_Medals= olympics.Country.value_counts().nlargest(10)
Top_10_Countries_by_Medals
# Out:
# Country
# United States     4585
# Soviet Union      2049
# United Kingdom    1720
# France            1396
# Germany           1305
# Italy             1296
# Australia         1189
# Hungary           1079
# Sweden            1044
# Netherlands        851
# Name: count, dtype: int64

# %%
Top_10_Countries_by_Medals.plot(kind = "bar", fontsize = 16, figsize=(15,12) , color=('cyan'))
plt.title("Top 10 Countries by Medals", fontsize= 18)
plt.xlabel("Country",  fontsize= 18)
plt.ylabel("Medals" ,  fontsize= 18)
plt.show()

# %% [markdown]
# #### Split the total medals of Top 10 Countries into Summer / Winter. Are there typical Summer/Winter Games Countries?

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale=1.3, palette= "dark")
sns.countplot(data = olympics, x = "Country", color = ('darkviolet'), order = Top_10_Countries_by_Medals.index)
plt.xlabel("Country")
plt.ylabel("Total Medals")
plt.title("Top 10 Countries by Medals", fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale=1.5, palette= "dark")
sns.countplot(data = olympics, x = "Country", hue = "Edition", order = Top_10_Countries_by_Medals.index)
plt.title("Top 10 Countries by Medals", fontsize = 20)
plt.show()

# %% [markdown]
# #### Split the total medals of Top 10 Countries into Gold, Silver, Bronze

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale=1.5, palette= "dark")
sns.countplot(data = olympics, x = "Country", hue = "Medal", order =Top_10_Countries_by_Medals.index,
              hue_order = ["Gold", "Silver", "Bronze"], palette = ["gold", "Gray", "darkgoldenrod"])
plt.title("Top 10 Countries by Medals", fontsize = 20)
plt.show()
